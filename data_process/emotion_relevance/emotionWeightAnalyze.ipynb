# %% [markdown]
# This notebook should be processed after the initial pre-processing data

# %%
# import warnings
# warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import sys
import os

# use only for dictionary parsing...
import ast

# %% [markdown]
# # 1. Modify processed dataset

# %%
dataDevEmotionMultipleSentence = pd.read_csv('dev/emotion/allcharlinepairs-withoutPlutchikVoting-v1.csv')
dataDevEmotionMultipleSentence['emotion'] = [list(x.strip('[').strip(']').strip('\"').strip().replace("\", \"", ", ").replace("\'", "").split(', ')) 
                              for x in dataDevEmotionMultipleSentence['emotion']]
dataDevEmotionMultipleSentence['plutchik'] = [ast.literal_eval(x) for x in dataDevEmotionMultipleSentence['plutchik']]

dataDevEmotionMultipleSentence = dataDevEmotionMultipleSentence.drop(labels='Unnamed: 0',axis=1)
dataDevEmotionMultipleSentence.index.names = ['index']
dataDevEmotionMultipleSentence = dataDevEmotionMultipleSentence.reset_index()
dataDevEmotionMultipleSentence
# Out:
#        index                               storyid  linenum        char  \
# 0          0  a2ddbb50-e45b-4ad3-becf-b2d8475172bf        1  I (myself)
# 1          1  a2ddbb50-e45b-4ad3-becf-b2d8475172bf        1  I (myself)
# 2          2  a2ddbb50-e45b-4ad3-becf-b2d8475172bf        1  I (myself)
# 3          3  a2ddbb50-e45b-4ad3-becf-b2d8475172bf        2  I (myself)
# 4          4  a2ddbb50-e45b-4ad3-becf-b2d8475172bf        2  I (myself)
# ...      ...                                   ...      ...         ...
# 42949  42949  2aa1aca3-9264-4e27-9ebb-fa5de8e7e84e        4      Marcus
# 42950  42950  2aa1aca3-9264-4e27-9ebb-fa5de8e7e84e        4      Marcus
# 42951  42951  2aa1aca3-9264-4e27-9ebb-fa5de8e7e84e        5      Marcus
# 42952  42952  2aa1aca3-9264-4e27-9ebb-fa5de8e7e84e        5      Marcus
# 42953  42953  2aa1aca3-9264-4e27-9ebb-fa5de8e7e84e        5      Marcus
#
#       emotionworkerid                                            context  \
# 0                ann0                                                NaN
# 1                ann1                                                NaN
# 2                ann2                                                NaN
# 3                ann1  I began making fish curry for my boyfriend and I.
# 4                ann2  I began making fish curry for my boyfriend and I.
# ...               ...                                                ...
# 42949            ann1  Marcus was collecting shells on the beach.|He ...
# 42950            ann2  Marcus was collecting shells on the beach.|He ...
# 42951            ann0  Marcus was collecting shells on the beach.|He ...
# 42952            ann1  Marcus was collecting shells on the beach.|He ...
# 42953            ann2  Marcus was collecting shells on the beach.|He ...
#
#                                                 sentence affected  \
# 0      I began making fish curry for my boyfriend and I.      yes
# 1      I began making fish curry for my boyfriend and I.      yes
# 2      I began making fish curry for my boyfriend and I.      yes
# 3      I decided not to read a recipe since I've made...      yes
# 4      I decided not to read a recipe since I've made...      yes
# ...                                                  ...      ...
# 42949                    Suddenly he felt a sharp pinch.      yes
# 42950                    Suddenly he felt a sharp pinch.      yes
# 42951      A crab was inside the shell pinching his leg.      yes
# 42952      A crab was inside the shell pinching his leg.      yes
# 42953      A crab was inside the shell pinching his leg.      yes
#
#                       emotion  \
# 0              [joy, excited]
# 1                   [content]
# 2      [hungry, anticipation]
# 3                   [excited]
# 4                 [confident]
# ...                       ...
# 42949                  [sore]
# 42950             [surprised]
# 42951               [shocked]
# 42952             [surprised]
# 42953                [pained]
#
#                                                 plutchik
# 0      {'joy': 3, 'trust': 3, 'fear': 0, 'surprise': ...
# 1      {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 2      {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 3      {'joy': 3, 'trust': 3, 'fear': 0, 'surprise': ...
# 4      {'joy': 2, 'trust': 3, 'fear': 0, 'surprise': ...
# ...                                                  ...
# 42949  {'joy': 2, 'trust': 2, 'fear': 2, 'surprise': ...
# 42950  {'joy': 2, 'trust': 0, 'fear': 2, 'surprise': ...
# 42951  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 42952  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 42953  {'joy': 0, 'trust': 0, 'fear': 3, 'surprise': ...
#
# [42954 rows x 10 columns]

# %%
dataTestEmotionMultipleSentence = pd.read_csv('test/emotion/allcharlinepairs-withoutPlutchikVoting-v1.csv')
dataTestEmotionMultipleSentence['emotion'] = [list(x.strip('[').strip(']').strip('\"').strip().replace("\", \"", ", ").replace("\'", "").split(', ')) 
                              for x in dataTestEmotionMultipleSentence['emotion']]
dataTestEmotionMultipleSentence['plutchik'] = [ast.literal_eval(x) for x in dataTestEmotionMultipleSentence['plutchik']]

dataTestEmotionMultipleSentence = dataTestEmotionMultipleSentence.drop(labels='Unnamed: 0',axis=1)
dataTestEmotionMultipleSentence.index.names = ['index']
dataTestEmotionMultipleSentence = dataTestEmotionMultipleSentence.reset_index()
dataTestEmotionMultipleSentence
# Out:
#        index                               storyid  linenum      char  \
# 0          0  a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 1          1  a3e66276-ef27-426f-8a2f-329779f17038        1      Cook
# 2          2  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 3          3  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# 4          4  a3e66276-ef27-426f-8a2f-329779f17038        2      Cook
# ...      ...                                   ...      ...       ...
# 43190  43190  9b53627e-41e5-47e6-9c6c-74d485572958        3  Rosemary
# 43191  43191  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 43192  43192  9b53627e-41e5-47e6-9c6c-74d485572958        4  Rosemary
# 43193  43193  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
# 43194  43194  9b53627e-41e5-47e6-9c6c-74d485572958        5  Rosemary
#
#       emotionworkerid                                            context  \
# 0                ann0                                                NaN
# 1                ann1                                                NaN
# 2                ann0  A cook was carrying an armful of oranged in th...
# 3                ann1  A cook was carrying an armful of oranged in th...
# 4                ann2  A cook was carrying an armful of oranged in th...
# ...               ...                                                ...
# 43190            ann2  Rosemary was eating a snack.|She was at a part...
# 43191            ann0  Rosemary was eating a snack.|She was at a part...
# 43192            ann1  Rosemary was eating a snack.|She was at a part...
# 43193            ann1  Rosemary was eating a snack.|She was at a part...
# 43194            ann2  Rosemary was eating a snack.|She was at a part...
#
#                                                 sentence affected  \
# 0      A cook was carrying an armful of oranged in th...      yes
# 1      A cook was carrying an armful of oranged in th...      yes
# 2               He dropped one on the floor by accident.      yes
# 3               He dropped one on the floor by accident.      yes
# 4               He dropped one on the floor by accident.      yes
# ...                                                  ...      ...
# 43190   She had been dieting for weeks and was starving.      yes
# 43191       After she stuffed herself, she regretted it.      yes
# 43192       After she stuffed herself, she regretted it.      yes
# 43193          Rosemary swore to eat healthier tomorrow.      yes
# 43194          Rosemary swore to eat healthier tomorrow.      yes
#
#                  emotion                                           plutchik
# 0                  [joy]  {'joy': 3, 'trust': 3, 'fear': 0, 'surprise': ...
# 1      [useful, nervous]  {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 2              [annoyed]  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 3                [angry]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 4           [frustrated]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# ...                  ...                                                ...
# 43190         [famished]  {'joy': 3, 'trust': 3, 'fear': 0, 'surprise': ...
# 43191            [gross]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 43192           [regret]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 43193          [ashamed]  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 43194      [comfortable]  {'joy': 3, 'trust': 2, 'fear': 0, 'surprise': ...
#
# [43195 rows x 10 columns]

# %%
# set the dataframe going to analyzed
currentAnalyze = dataTestEmotionMultipleSentence

# %% [markdown]
# # Modified plutchik analyze
# ## 2.1 Standard plutchik(including no emotion case)

# %%
for index, row in currentAnalyze.iterrows():
    tempalteOrder = {'joy' : 0, 'trust' : 0, 'fear' : 0, 'surprise' : 0, 'sadness' : 0, 'disgust' : 0, 'anger' : 0, 'anticipation' : 0}
    for key, value in row['plutchik'].items():
        tempalteOrder[key] = value
    currentAnalyze['plutchik'][index] = tempalteOrder.copy()
    print("\r", end="")
    print("2.1 Standard plutchik(including no emotion case) -> start conversion, current progress: {}/{} ".format(index+1, currentAnalyze.shape[0]), end="")
# Out:
# C:\Users\JAM_0\AppData\Local\Temp/ipykernel_19504/2464059937.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   currentAnalyze['plutchik'][index] = tempalteOrder.copy()
# 2.1 Standard plutchik(including no emotion case) -> start conversion, current progress: 43195/43195

# %% [markdown]
# ### 2.2 Modify emotion

# %%
currentAnalyze['emotion'] = currentAnalyze.emotion.map(lambda x: {emotion : 1 for emotion in x })

# %% [markdown]
# ### 2.3 Voting

# %%
# EMOTION 加一个weight，表达程度
# 确认同义词的定义（一个人是否同时说happy, glad...）
mainPosIndex = pd.Series(False, index = currentAnalyze.index)
for index, row in currentAnalyze.iterrows():
    if (index == 0 or currentEditting['sentence'] != row['sentence']): # case: new sentence, update CURRENT adding
        if (index != 0):
            for key in currentEditting['plutchik']:
                # print(index - currentEditting[0], "previous: ", currentEditting[1]['plutchik'][key])
                currentEditting['plutchik'][key] //= index - currentEditting[0]
            for i in range(currentEditting['index'] + 1, index):
                for emotion in currentAnalyze['emotion'][i]:
                    currentAnalyze['emotion'][currentEditting['index']][emotion] = currentAnalyze['emotion'][currentEditting['index']].get(emotion, 0) + 1 
        currentEditting = currentAnalyze.iloc[index]
        mainPosIndex[currentEditting['index']] = True
    else: # case: same as previous sentence, do voting
        for key, value in currentAnalyze['plutchik'][index].items():
            currentAnalyze['plutchik'][currentEditting['index']][key] += value
    print("\r", end="")
    print("2.2 Voting -> start voting, current progress: {}/{} ".format(index+1, currentAnalyze.shape[0]), end="")
    
# dealing last case
for key in currentEditting['plutchik']:
    # print(index - currentEditting[0], "previous: ", currentEditting[1]['plutchik'][key])
    currentEditting['plutchik'][key] //= index - currentEditting[0]
for i in range(currentEditting['index'] + 1, index):
    for emotion in currentAnalyze['emotion'][i]:
        currentAnalyze['emotion'][currentEditting['index']][emotion] = currentAnalyze['emotion'][currentEditting['index']].get(emotion, 0) + 1
# Out:
# 2.2 Voting -> start voting, current progress: 43195/43195

# %%
currentAnalyze = currentAnalyze[mainPosIndex]
currentAnalyze = currentAnalyze.drop(labels='index',axis=1)
currentAnalyze = currentAnalyze.reset_index(drop=True)
currentAnalyze.index.names = ['index']
currentAnalyze = currentAnalyze.reset_index()

# %%
currentAnalyze
currentAnalyze[50:100]
# Out:
#     index                               storyid  linenum        char  \
# 50     50  f2d8627a-62d8-4fce-a541-c92ca5f6fb43        5        Tony
# 51     51  7c7d5b3b-43fa-4365-88ee-647fd67d4d02        1       Lance
# 52     52  7c7d5b3b-43fa-4365-88ee-647fd67d4d02        2       Lance
# 53     53  7c7d5b3b-43fa-4365-88ee-647fd67d4d02        3       Lance
# 54     54  7c7d5b3b-43fa-4365-88ee-647fd67d4d02        4       Lance
# 55     55  7c7d5b3b-43fa-4365-88ee-647fd67d4d02        5       Lance
# 56     56  c2721c6a-a4f2-4a6f-a785-db53fa3955c2        1         Jim
# 57     57  c2721c6a-a4f2-4a6f-a785-db53fa3955c2        2         Jim
# 58     58  c2721c6a-a4f2-4a6f-a785-db53fa3955c2        3         Jim
# 59     59  c2721c6a-a4f2-4a6f-a785-db53fa3955c2        4         Jim
# 60     60  c2721c6a-a4f2-4a6f-a785-db53fa3955c2        5         Jim
# 61     61  3453b215-b608-49e8-950e-dc16a4e129cb        1      Jeremy
# 62     62  3453b215-b608-49e8-950e-dc16a4e129cb        2      Jeremy
# 63     63  3453b215-b608-49e8-950e-dc16a4e129cb        3      Jeremy
# 64     64  3453b215-b608-49e8-950e-dc16a4e129cb        4      Jeremy
# 65     65  3453b215-b608-49e8-950e-dc16a4e129cb        5      Jeremy
# 66     66  e72c9df2-39fc-4f1f-a175-0c25e127d3ef        1      People
# 67     67  e72c9df2-39fc-4f1f-a175-0c25e127d3ef        2  I (myself)
# 68     68  e72c9df2-39fc-4f1f-a175-0c25e127d3ef        3  I (myself)
# 69     69  e72c9df2-39fc-4f1f-a175-0c25e127d3ef        4  I (myself)
# 70     70  e72c9df2-39fc-4f1f-a175-0c25e127d3ef        5  I (myself)
# 71     71  4de75bab-ae6c-4287-a5bb-b793ac9fed2e        1         Bob
# 72     72  4de75bab-ae6c-4287-a5bb-b793ac9fed2e        2         Bob
# 73     73  4de75bab-ae6c-4287-a5bb-b793ac9fed2e        3         Bob
# 74     74  4de75bab-ae6c-4287-a5bb-b793ac9fed2e        4         Bob
# 75     75  4de75bab-ae6c-4287-a5bb-b793ac9fed2e        5         Bob
# 76     76  ad57a803-1cc8-4afc-94c3-3446d8d1cafb        2     Friends
# 77     77  ad57a803-1cc8-4afc-94c3-3446d8d1cafb        3  I (myself)
# 78     78  ad57a803-1cc8-4afc-94c3-3446d8d1cafb        4  I (myself)
# 79     79  ad57a803-1cc8-4afc-94c3-3446d8d1cafb        5  I (myself)
# 80     80  575015b7-aa6b-4587-9e4a-c26409c78659        1         Liv
# 81     81  575015b7-aa6b-4587-9e4a-c26409c78659        2         Liv
# 82     82  575015b7-aa6b-4587-9e4a-c26409c78659        3         Liv
# 83     83  575015b7-aa6b-4587-9e4a-c26409c78659        4         Liv
# 84     84  575015b7-aa6b-4587-9e4a-c26409c78659        5         Liv
# 85     85  6047974c-62e8-434e-9e3d-a4a71a0ba76f        1         Jim
# 86     86  6047974c-62e8-434e-9e3d-a4a71a0ba76f        2         Bob
# 87     87  6047974c-62e8-434e-9e3d-a4a71a0ba76f        3         Bob
# 88     88  6047974c-62e8-434e-9e3d-a4a71a0ba76f        4         Bob
# 89     89  6047974c-62e8-434e-9e3d-a4a71a0ba76f        5         Bob
# 90     90  8e85aa8e-3d87-4068-a128-bbafdb4840d3        1        Fran
# 91     91  8e85aa8e-3d87-4068-a128-bbafdb4840d3        2        Fran
# 92     92  8e85aa8e-3d87-4068-a128-bbafdb4840d3        3        Fran
# 93     93  8e85aa8e-3d87-4068-a128-bbafdb4840d3        4        Fran
# 94     94  8e85aa8e-3d87-4068-a128-bbafdb4840d3        5        Fran
# 95     95  84d5da24-7501-4ce4-8281-33eac5288d13        1       Billy
# 96     96  84d5da24-7501-4ce4-8281-33eac5288d13        2       Billy
# 97     97  84d5da24-7501-4ce4-8281-33eac5288d13        3       Billy
# 98     98  84d5da24-7501-4ce4-8281-33eac5288d13        4       Billy
# 99     99  84d5da24-7501-4ce4-8281-33eac5288d13        5       Billy
#
#    emotionworkerid                                            context  \
# 50            ann0  Tony has a Siberian husky.|It sheds fur everyw...
# 51            ann0                                                NaN
# 52            ann0             Last week Lance told a hilarious joke.
# 53            ann0  Last week Lance told a hilarious joke.|None of...
# 54            ann0  Last week Lance told a hilarious joke.|None of...
# 55            ann0  Last week Lance told a hilarious joke.|None of...
# 56            ann0                                                NaN
# 57            ann0          Jim was sitting in his house one morning.
# 58            ann0  Jim was sitting in his house one morning.|Sudd...
# 59            ann0  Jim was sitting in his house one morning.|Sudd...
# 60            ann0  Jim was sitting in his house one morning.|Sudd...
# 61            ann0                                                NaN
# 62            ann0   Jeremy bought diving equipment and took lessons.
# 63            ann0  Jeremy bought diving equipment and took lesson...
# 64            ann0  Jeremy bought diving equipment and took lesson...
# 65            ann0  Jeremy bought diving equipment and took lesson...
# 66            ann0                                                NaN
# 67            ann0     Painting isn't as hard as people make it seem.
# 68            ann0  Painting isn't as hard as people make it seem....
# 69            ann0  Painting isn't as hard as people make it seem....
# 70            ann0  Painting isn't as hard as people make it seem....
# 71            ann0                                                NaN
# 72            ann0                   Bob was driving up his driveway.
# 73            ann0  Bob was driving up his driveway.|He hit a deep...
# 74            ann0  Bob was driving up his driveway.|He hit a deep...
# 75            ann0  Bob was driving up his driveway.|He hit a deep...
# 76            ann0                I was solving a rubix cube at home.
# 77            ann0  I was solving a rubix cube at home.|My friends...
# 78            ann0  I was solving a rubix cube at home.|My friends...
# 79            ann0  I was solving a rubix cube at home.|My friends...
# 80            ann0                                                NaN
# 81            ann0   Liv was a budding artist and she loved painting.
# 82            ann0  Liv was a budding artist and she loved paintin...
# 83            ann0  Liv was a budding artist and she loved paintin...
# 84            ann0  Liv was a budding artist and she loved paintin...
# 85            ann0                                                NaN
# 86            ann0                       Jim made suits for a living.
# 87            ann0  Jim made suits for a living.|Bob came into Jim...
# 88            ann0  Jim made suits for a living.|Bob came into Jim...
# 89            ann0  Jim made suits for a living.|Bob came into Jim...
# 90            ann0                                                NaN
# 91            ann0                  Fran had a delicious cake recipe.
# 92            ann0  Fran had a delicious cake recipe.|Her friends ...
# 93            ann0  Fran had a delicious cake recipe.|Her friends ...
# 94            ann0  Fran had a delicious cake recipe.|Her friends ...
# 95            ann0                                                NaN
# 96            ann0     In August Billy is going overseas for the war.
# 97            ann0  In August Billy is going overseas for the war....
# 98            ann0  In August Billy is going overseas for the war....
# 99            ann0  In August Billy is going overseas for the war....
#
#                                              sentence affected  \
# 50                         Now he vacuums every week.      yes
# 51             Last week Lance told a hilarious joke.      yes
# 52                            None of us expected it.      yes
# 53   Jimbo laughed so hard milk came out of his nose.      yes
# 54                That made everyone laugh even more.      yes
# 55                     Which made more milk come out.      yes
# 56          Jim was sitting in his house one morning.      yes
# 57                      Suddenly, the power went out.      yes
# 58      He realized he had forgotten to pay his bill.      yes
# 59                    He called the electric company.      yes
# 60  They charged him a huge fee to restart his ser...      yes
# 61   Jeremy bought diving equipment and took lessons.      yes
# 62  When he got good enough, he made plans to dive...      yes
# 63  Later, he went out to the lake with his gear a...      yes
# 64  He swam around and found treasures at the bott...      yes
# 65  Jeremy happily swam to the surface with his ne...      yes
# 66     Painting isn't as hard as people make it seem.      yes
# 67  Last week I bought some canvas and gave it a try.      yes
# 68  My friend loaned me some paints and I went to ...      yes
# 69                      I made a beautiful landscape.      yes
# 70  It's being showcased in an art gallery next mo...      yes
# 71                   Bob was driving up his driveway.      yes
# 72                    He hit a deep rut with his car.      yes
# 73           Bob's soda spilled all over the console.      yes
# 74                  Bob kept driving up the driveway.      yes
# 75  When he got to his house, he cleaned up the sp...      yes
# 76                         My friends wanted to help.      yes
# 77               I told them I wanted to do it alone.      yes
# 78                    After an hour I was frustrated.      yes
# 79  When I passed it to my friends, they solved it...      yes
# 80   Liv was a budding artist and she loved painting.      yes
# 81  She wanted to go to art classes, but her schoo...      yes
# 82  So Liv got together with her friends and began...      yes
# 83  They decided to form their own art group at th...      yes
# 84  They made an after-school art club and named L...      yes
# 85                       Jim made suits for a living.      yes
# 86  Bob came into Jim's shop and asked for a very ...      yes
# 87  Jim told him this would take a long time to make.      yes
# 88                 Bob said he needed it in two days.      yes
# 89  Jim worked day and night and he finished the s...      yes
# 90                  Fran had a delicious cake recipe.      yes
# 91  Her friends encouraged her to enter a baking c...      yes
# 92   Fran was nervous, but decided to give it a shot.      yes
# 93        Fran entered her cake into the competition.      yes
# 94   Everyone loved her cake and she won first place.      yes
# 95     In August Billy is going overseas for the war.      yes
# 96  He doesn't want to say goodbye to his wife, ki...      yes
# 97  He talks to his friend Tom about looking over ...      yes
# 98              Billy feels better about leaving now.      yes
# 99  Now Bill only focuses on the war, and serving ...      yes
#
#                                               emotion  \
# 50    {'resigned': 1, 'overwhelmed': 1, 'annoyed': 1}
# 51                       {'happy': 2, 'satisfied': 1}
# 52        {'prideful': 1, 'enjoy': 1, 'confident': 1}
# 53  {'proud': 1, 'happy': 2, 'embarrassed': 1, 'am...
# 54  {'relaxed': 1, 'appreciated': 1, 'smart': 1, '...
# 55  {'amused': 2, 'happy': 1, 'joyful': 1, 'humore...
# 56              {'calm': 1, 'content': 1, 'tired': 1}
# 57     {'shocked': 1, 'concerned': 1, 'surprised': 1}
# 58       {'forgetful': 1, 'worried': 1, 'ashamed': 1}
# 59  {'sad': 1, 'afraid': 1, 'nervous': 1, 'embarra...
# 60  {'aggravated': 1, 'miserable': 1, 'upset': 1, ...
# 61                                     {'excited': 3}
# 62                         {'excited': 2, 'proud': 1}
# 63          {'eager': 1, 'excited': 1, 'thrilled': 1}
# 64  {'elated': 1, 'surprised': 1, 'excited': 2, 'h...
# 65           {'shocked': 1, 'excited': 1, 'happy': 1}
# 66           {'fear': 1, 'amazed': 1, 'disbelief': 1}
# 67  {'accomplished': 1, 'intrepid': 1, 'excited': ...
# 68  {'excited': 1, 'happy': 1, 'confident': 1, 'ge...
# 69  {'happy': 2, 'proud': 1, 'generous': 1, 'antic...
# 70  {'proud': 3, 'impressed': 2, 'trust': 1, 'enco...
# 71        {'anxious': 1, 'excited': 1, 'peaceful': 1}
# 72                         {'shocked': 2, 'upset': 1}
# 73  {'aggravated': 1, 'frustrated': 1, 'disappoint...
# 74            {'annoyed': 1, 'soaked': 1, 'angry': 1}
# 75                     {'clumsy': 2, 'frustrated': 1}
# 76            {'helpful': 1, 'smart': 1, 'useful': 1}
# 77  {'focused': 1, 'independent': 1, 'challenged':...
# 78  {'annoyed': 2, 'irritated': 1, 'frustrated': 1...
# 79  {'annoyed': 2, 'frustrated': 1, 'smug': 1, 'sm...
# 80                         {'happy': 3, 'hopeful': 1}
# 81    {'sad': 2, 'disappointed': 1, 'indifferent': 1}
# 82  {'anticipation': 1, 'competent': 1, 'excited': 1}
# 83          {'happy': 1, 'excited': 1, 'pleasant': 1}
# 84  {'proud': 2, 'happy': 2, 'shocked': 1, 'eager'...
# 85      {'happy': 1, 'responsible': 1, 'creative': 1}
# 86  {'peppy': 1, 'accomplished': 1, 'excited': 2, ...
# 87  {'disappointing': 1, 'curious': 1, 'excited': ...
# 88  {'competent': 1, 'rushed': 2, 'impatient': 1, ...
# 89  {'exultant': 1, 'blithe': 1, 'pleased': 1, 're...
# 90         {'proud': 1, 'excited': 1, 'satisfied': 1}
# 91    {'proud': 1, 'anticipation': 1, 'flattered': 1}
# 92  {'determined': 1, 'hopeful': 1, 'nervous': 1, ...
# 93                          {'hopeful': 1, 'fear': 1}
# 94  {'accomplished': 1, 'elated': 1, 'happy': 2, '...
# 95      {'responsible': 1, 'anxious': 1, 'scared': 1}
# 96                         {'sad': 2, 'depressed': 1}
# 97  {'excited': 1, 'scared': 2, 'anxious': 1, 'sad...
# 98             {'reassured': 1, 'relieved': 1, '': 1}
# 99  {'patriotic': 3, 'focused': 1, 'focus': 1, 'mi...
#
#                                              plutchik
# 50  {'joy': 0, 'trust': 0, 'fear': 1, 'surprise': ...
# 51  {'joy': 3, 'trust': 0, 'fear': 0, 'surprise': ...
# 52  {'joy': 3, 'trust': 1, 'fear': 0, 'surprise': ...
# 53  {'joy': 2, 'trust': 1, 'fear': 0, 'surprise': ...
# 54  {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 55  {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 56  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 57  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 58  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 59  {'joy': 0, 'trust': 0, 'fear': 1, 'surprise': ...
# 60  {'joy': 0, 'trust': 0, 'fear': 1, 'surprise': ...
# 61  {'joy': 3, 'trust': 1, 'fear': 0, 'surprise': ...
# 62  {'joy': 3, 'trust': 1, 'fear': 0, 'surprise': ...
# 63  {'joy': 2, 'trust': 1, 'fear': 0, 'surprise': ...
# 64  {'joy': 3, 'trust': 0, 'fear': 0, 'surprise': ...
# 65  {'joy': 3, 'trust': 0, 'fear': 0, 'surprise': ...
# 66  {'joy': 1, 'trust': 0, 'fear': 1, 'surprise': ...
# 67  {'joy': 1, 'trust': 0, 'fear': 0, 'surprise': ...
# 68  {'joy': 2, 'trust': 2, 'fear': 0, 'surprise': ...
# 69  {'joy': 2, 'trust': 1, 'fear': 0, 'surprise': ...
# 70  {'joy': 1, 'trust': 1, 'fear': 0, 'surprise': ...
# 71  {'joy': 1, 'trust': 0, 'fear': 0, 'surprise': ...
# 72  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 73  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 74  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 75  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 76  {'joy': 1, 'trust': 0, 'fear': 0, 'surprise': ...
# 77  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 78  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 79  {'joy': 1, 'trust': 0, 'fear': 0, 'surprise': ...
# 80  {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 81  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 82  {'joy': 2, 'trust': 1, 'fear': 0, 'surprise': ...
# 83  {'joy': 3, 'trust': 3, 'fear': 0, 'surprise': ...
# 84  {'joy': 2, 'trust': 2, 'fear': 0, 'surprise': ...
# 85  {'joy': 2, 'trust': 2, 'fear': 0, 'surprise': ...
# 86  {'joy': 2, 'trust': 1, 'fear': 0, 'surprise': ...
# 87  {'joy': 0, 'trust': 0, 'fear': 1, 'surprise': ...
# 88  {'joy': 0, 'trust': 1, 'fear': 0, 'surprise': ...
# 89  {'joy': 2, 'trust': 2, 'fear': 0, 'surprise': ...
# 90  {'joy': 2, 'trust': 1, 'fear': 0, 'surprise': ...
# 91  {'joy': 3, 'trust': 2, 'fear': 0, 'surprise': ...
# 92  {'joy': 0, 'trust': 0, 'fear': 1, 'surprise': ...
# 93  {'joy': 1, 'trust': 1, 'fear': 1, 'surprise': ...
# 94  {'joy': 3, 'trust': 0, 'fear': 0, 'surprise': ...
# 95  {'joy': 0, 'trust': 0, 'fear': 2, 'surprise': ...
# 96  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 97  {'joy': 0, 'trust': 0, 'fear': 1, 'surprise': ...
# 98  {'joy': 1, 'trust': 2, 'fear': 0, 'surprise': ...
# 99  {'joy': 1, 'trust': 1, 'fear': 1, 'surprise': ...

# %%
# output: dev
currentAnalyze = currentAnalyze.drop(labels='index',axis=1)
currentAnalyze.to_csv('dev/emotion/allcharlinepairs-withDataCleaning-v2.csv')

# %%
# output: test
currentAnalyze = currentAnalyze.drop(labels='index',axis=1)
currentAnalyze.to_csv('test/emotion/allcharlinepairs-withDataCleaning-v2.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19504/3909700187.py in <module>
#       1 # output: test
# ----> 2 currentAnalyze = currentAnalyze.drop(labels='index',axis=1)
#       3 currentAnalyze.to_csv('test/emotion/allcharlinepairs-withDataCleaning-v2.csv')
#
# C:\Python\miniconda3\envs\story_cloze\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Python\miniconda3\envs\story_cloze\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4952                 weight  1.0     0.8
#    4953         """
# -> 4954         return super().drop(
#    4955             labels=labels,
#    4956             axis=axis,
#
# C:\Python\miniconda3\envs\story_cloze\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# C:\Python\miniconda3\envs\story_cloze\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# C:\Python\miniconda3\envs\story_cloze\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6642         if mask.any():
#    6643             if errors != "ignore":
# -> 6644                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645             indexer = indexer[~mask]
#    6646         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"
