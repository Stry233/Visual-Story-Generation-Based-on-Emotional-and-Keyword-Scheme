# %%
# global var set
import transformers

# model info, change as needed
model_checkpoint = 'bert-base-uncased'
batch_size = 16
num_epochs = 16

# fileTag = "clean-v1"                      # clean + no phase + combine    (pure clean)
fileTag = "clean-phase-v1"                # clean +   phase  + combine
# fileTag = 'clean-phase-noCombin-v1'       # clean +   phase  + no combine
# fileTag = 'original-noCheat-noCombin-v1'  # raw   +   no Cheat case
# fileTag = 'original'                        # row   +   keep Cheat case     (pure raw) 

model_checkpoint
# Out:
# 'bert-base-uncased'

# %% [markdown]
# # Convert dataset to suitable format
# IMPORTANT: please never run this section again if you have your dataset ready!

# %%
import pandas as pd
from pandas import DataFrame

trainDatasetOriginal = pd.read_csv(f'../../data/csv_version/dev/emotion/allcharlinepairs-{fileTag}.csv')
testDatasetOriginal = pd.read_csv(f'../../data/csv_version/test/emotion/allcharlinepairs-{fileTag}.csv')

# %%
trainDatasetProcessed = DataFrame({'emotion' : trainDatasetOriginal['emotion'],
                                   'plutchik' : trainDatasetOriginal['plutchik'],
                                  'selection0': pd.concat([trainDatasetOriginal['sentence'][:trainDatasetOriginal.shape[0]//5], trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][trainDatasetOriginal.shape[0]//5:]]), 
                                  'selection1': pd.concat([trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:trainDatasetOriginal.shape[0]//5], 
                                                pd.concat([trainDatasetOriginal['sentence'][trainDatasetOriginal.shape[0]//5:trainDatasetOriginal.shape[0]//5*2], 
                                                trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][trainDatasetOriginal.shape[0]//5*2:]])]), 
                                  'selection2': pd.concat([trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:trainDatasetOriginal.shape[0]//5*2], 
                                                pd.concat([trainDatasetOriginal['sentence'][trainDatasetOriginal.shape[0]//5*2:trainDatasetOriginal.shape[0]//5*3], 
                                                trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][trainDatasetOriginal.shape[0]//5*3:]])]), 
                                  'selection3': pd.concat([trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:trainDatasetOriginal.shape[0]//5*3], 
                                                pd.concat([trainDatasetOriginal['sentence'][trainDatasetOriginal.shape[0]//5*3:trainDatasetOriginal.shape[0]//5*4], 
                                                trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][trainDatasetOriginal.shape[0]//5*4:]])]),
                                  'selection4': pd.concat([trainDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:trainDatasetOriginal.shape[0]//5*4], 
                                                           trainDatasetOriginal['sentence'][trainDatasetOriginal.shape[0]//5*4:]]),
                                  'label': pd.Series(0 if x < trainDatasetOriginal.shape[0]//5 else (1 if x < trainDatasetOriginal.shape[0]//5*2 
                                                                                               else (2 if x < trainDatasetOriginal.shape[0]//5*3 
                                                                                               else (3 if x < trainDatasetOriginal.shape[0]//5*4
                                                                                               else  4))) for x in trainDatasetOriginal.index)}).sample(frac=1).reset_index(drop=True)

testDatasetProcessed = DataFrame({'emotion' : testDatasetOriginal['emotion'],
                                   'plutchik' : testDatasetOriginal['plutchik'],
                                  'selection0': pd.concat([testDatasetOriginal['sentence'][:testDatasetOriginal.shape[0]//5], testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][testDatasetOriginal.shape[0]//5:]]), 
                                  'selection1': pd.concat([testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:testDatasetOriginal.shape[0]//5], 
                                                pd.concat([testDatasetOriginal['sentence'][testDatasetOriginal.shape[0]//5:testDatasetOriginal.shape[0]//5*2], 
                                                testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][testDatasetOriginal.shape[0]//5*2:]])]), 
                                  'selection2': pd.concat([testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:testDatasetOriginal.shape[0]//5*2], 
                                                pd.concat([testDatasetOriginal['sentence'][testDatasetOriginal.shape[0]//5*2:testDatasetOriginal.shape[0]//5*3], 
                                                testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][testDatasetOriginal.shape[0]//5*3:]])]), 
                                  'selection3': pd.concat([testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:testDatasetOriginal.shape[0]//5*3], 
                                                pd.concat([testDatasetOriginal['sentence'][testDatasetOriginal.shape[0]//5*3:testDatasetOriginal.shape[0]//5*4], 
                                                testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][testDatasetOriginal.shape[0]//5*4:]])]),
                                  'selection4': pd.concat([testDatasetOriginal.sample(frac = 1).reset_index()['sentence'][:testDatasetOriginal.shape[0]//5*4], 
                                                           testDatasetOriginal['sentence'][testDatasetOriginal.shape[0]//5*4:]]),
                                  'label': pd.Series(0 if x < testDatasetOriginal.shape[0]//5 else (1 if x < testDatasetOriginal.shape[0]//5*2 
                                                                                               else (2 if x < testDatasetOriginal.shape[0]//5*3 
                                                                                               else (3 if x < testDatasetOriginal.shape[0]//5*4
                                                                                               else  4))) for x in testDatasetOriginal.index)}).sample(frac=1).reset_index(drop=True)

# %%
trainDatasetProcessed.to_csv(f'./dataset/5Select-{fileTag}-train.csv')
trainDatasetProcessed
# Out:
#                                                  emotion  \
# 0                           ['okay', 'part', 'included']
# 1                           ['pro', 'anxious', 'rushed']
# 2      ['awful', 'upset', 'disappointed', 'embarrasse...
# 3                      ['bored', 'impatient', 'annoyed']
# 4                                     ['dirty', 'upset']
# ...                                                  ...
# 11605  ['satisfied', 'satisfaction', 'pride', 'achiev...
# 11606  ['understanding', 'uncomfortable', 'empty', 'n...
# 11607            ['annoyed', 'sad', 'betrayed', 'angry']
# 11608  ['hunger', 'defeat', 'hungry', 'innovative', '...
# 11609            ['intrigued', 'happy', 'contemplative']
#
#                                                 plutchik  \
# 0      {'joy': 1, 'trust': 1, 'fear': 0, 'surprise': ...
# 1      {'joy': 1, 'trust': 1, 'fear': 1, 'surprise': ...
# 2      {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 3      {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 4      {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# ...                                                  ...
# 11605  {'joy': 2, 'trust': 2, 'fear': 0, 'surprise': ...
# 11606  {'joy': 0, 'trust': 1, 'fear': 2, 'surprise': ...
# 11607  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 11608  {'joy': 1, 'trust': 1, 'fear': 0, 'surprise': ...
# 11609  {'joy': 3, 'trust': 1, 'fear': 0, 'surprise': ...
#
#                                               selection0  \
# 0                         Ricky called his dad for help.
# 1                I stopped at a blockbuster video store.
# 2      She felt like she was an adult so she made cup...
# 3                          They objected to their union.
# 4                                      Amy went camping.
# ...                                                  ...
# 11605  Phil put a tape recorder in his shirt pocket a...
# 11606                   Oscar drove home in his new car.
# 11607  Kay was upset since the coupons would have sav...
# 11608             They put them between graham crackers.
# 11609  At practice, the other members told him he was...
#
#                                               selection1  \
# 0      Neil was impressed by the amount of work done ...
# 1      She read that the inside of a banana peel help...
# 2      His mom made an appointment with the barber fo...
# 3      One of my daughter's friends got married a few...
# 4      So on her next test, she failed a question, go...
# ...                                                  ...
# 11605  Boris didn't really understand the meaning beh...
# 11606         She said she felt naked without the cross.
# 11607                          Her child started to cry.
# 11608  I'm sure glad our apartment complex has a pool...
# 11609   Roger was okay though he only got a few bruises.
#
#                                               selection2  \
# 0                               She ran to the bathroom.
# 1                  Ben's wristwatch had stopped working.
# 2               The toughest gal around wanted to fight.
# 3      The baby settled in Chad's lap at the bottom o...
# 4                                Her hair was so greasy!
# ...                                                  ...
# 11605  After installation, Dan realized his house was...
# 11606  His mind was flooded with old memories from hi...
# 11607  When she was moving towards one, another car c...
# 11608       Peter eventually recovered from his illness.
# 11609                  The cop gave the person a ticket.
#
#                                               selection3  \
# 0                  He bought the ticket through a proxy.
# 1      Cameron looked outside the open door of the pl...
# 2          She was so uncomfortable, she had to go home.
# 3        I began to get tired of using the same crayons.
# 4                  Bill was on boating while on holiday.
# ...                                                  ...
# 11605  He would buy ten tacos and eat them all under ...
# 11606     Much of it was unsavory and hurt his business.
# 11607       Michelle didn't make the cheerleading squad.
# 11608  Their parents blamed Jane and she was very ash...
# 11609     Shawn falls in love with the dog at the store.
#
#                                               selection4  label
# 0      Andrea didn't want to be an outcast, so she at...      4
# 1                                       So I sped it up.      4
# 2             This place had the best doughnuts in town.      3
# 3          Ellen had a huge crush on her classmate Evan.      3
# 4      She was expecting to eat a nice dinner that ni...      2
# ...                                                  ...    ...
# 11605                  She went to four different shops.      2
# 11606  When I got into the water I realized that it w...      1
# 11607  Their babysitter informed them that their kid ...      1
# 11608  The teacher handed the class their exams to take.      0
# 11609         Marcus was collecting shells on the beach.      4
#
# [11610 rows x 8 columns]

# %%
testDatasetProcessed.to_csv(f'./dataset/5Select-{fileTag}-test.csv')
testDatasetProcessed
# Out:
#                                                  emotion  \
# 0                 ['upset', 'frustrated', 'unsatisfied']
# 1                                   ['happy', 'excited']
# 2                   ['foolish', 'annoyed', 'frustrated']
# 3                                    ['happy', 'hungry']
# 4                        ['proud', 'pride', 'competent']
# ...                                                  ...
# 11124  ['disappointed', 'annoyed', 'angry', 'aggravat...
# 11125          ['happy', 'glad', 'thankful', 'motherly']
# 11126     ['sad', 'angry', 'disappointed', 'distraught']
# 11127             ['aggravated', 'incapable', 'annoyed']
# 11128  ['touched', 'happy', 'grateful', 'thankful', '...
#
#                                                 plutchik  \
# 0      {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 1      {'joy': 3, 'trust': 0, 'fear': 0, 'surprise': ...
# 2      {'joy': 0, 'trust': 0, 'fear': 1, 'surprise': ...
# 3      {'joy': 1, 'trust': 0, 'fear': 0, 'surprise': ...
# 4      {'joy': 3, 'trust': 1, 'fear': 0, 'surprise': ...
# ...                                                  ...
# 11124  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 11125  {'joy': 2, 'trust': 0, 'fear': 0, 'surprise': ...
# 11126  {'joy': 0, 'trust': 0, 'fear': 0, 'surprise': ...
# 11127  {'joy': 0, 'trust': 1, 'fear': 0, 'surprise': ...
# 11128  {'joy': 2, 'trust': 1, 'fear': 0, 'surprise': ...
#
#                                               selection0  \
# 0      The captain gasped and they hit the underside ...
# 1                 He decided on spectacular New Zealand.
# 2                    Anthony was Charles' little cousin.
# 3           I had a golden retriever when I was younger.
# 4        At one time most major cities ran PCC trolleys.
# ...                                                  ...
# 11124  When he walked over to his pool, he noticed th...
# 11125  This spring they took a cruise from Boston to ...
# 11126                      I had a huge crush on Robbie.
# 11127  Now I love using text messages as a quick emai...
# 11128  Ivy was so touched and pleased by human kindness!
#
#                                               selection1  \
# 0      Reading and the motion of the bus soon lulled ...
# 1              Fiona was driving her car one wintry day.
# 2                        Tim wound up drinking too much.
# 3      She placed the meat first, in order to cook it...
# 4                  She was very grateful and thanked me.
# ...                                                  ...
# 11124               I used to go to church all the time.
# 11125  She went through catalogs and made note of the...
# 11126       She was very pleased with the delicious pie.
# 11127  Coming to a large fenced in area, John let Cha...
# 11128  John frowned, and forked over the money to his...
#
#                                               selection2  \
# 0                               I fell and hurt my back.
# 1                                 James won the tickets.
# 2                           I had cracked a head gasket.
# 3                  The principal told his bully to stop.
# 4           Her mother loved the gift and thanked Sally.
# ...                                                  ...
# 11124     They got into a fight and went to sleep angry.
# 11125  She pulled out the kitchen stool and took a step.
# 11126  John's wife told him the air freshener did not...
# 11127                 The players rushed onto the field.
# 11128  Jake called home to say he was working some ex...
#
#                                               selection3  \
# 0               Then she realized she was out of butter.
# 1      Suddenly he was awakened when his tent caught ...
# 2      Omar's dad six years ago just before Father's ...
# 3                             He promised her the world.
# 4                     The music store was a big success.
# ...                                                  ...
# 11124  As a result, Dennis had to learn not to be so ...
# 11125  I have a son that I go to the park to play bas...
# 11126  Night began to fall so he looked for shelter t...
# 11127  She called her best friend to see if she had r...
# 11128          Bob had a stuffed bear when he was young.
#
#                                               selection4  label
# 0                   They put new staples in the stapler.      3
# 1               Then she visited the Garden of the Gods.      2
# 2      After several weeks, he realized he hated grow...      2
# 3      A bigger goat knocked the food right out of he...      1
# 4                             I tried to hold my stance.      3
# ...                                                  ...    ...
# 11124  Ben finished hanging the picture and then trea...      2
# 11125                He paid very little money for them.      3
# 11126        The marriage didn't last and they divorced.      4
# 11127        The plow did not move the snow to the side.      4
# 11128  I picked up a handful of corn and threw it at ...      0
#
# [11129 rows x 8 columns]

# %% [markdown]
# # load dataset

# %%
from datasets import load_dataset, load_metric

# %%
dataset = load_dataset('csv', data_files={'train': f'./dataset/5Select-{fileTag}-train.csv', 
                                           'test': f'./dataset/5Select-{fileTag}-test.csv'})
# Out:
# Using custom data configuration default-b12ec4739f83f5c3
# Reusing dataset csv (C:\Users\JAM_0\.cache\huggingface\datasets\csv\default-b12ec4739f83f5c3\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'emotion', 'plutchik', 'selection0', 'selection1', 'selection2', 'selection3', 'selection4', 'label'],
#         num_rows: 11610
#     })
#     test: Dataset({
#         features: ['Unnamed: 0', 'emotion', 'plutchik', 'selection0', 'selection1', 'selection2', 'selection3', 'selection4', 'label'],
#         num_rows: 11129
#     })
# })

# %%
dataset['test'][0]
# Out:
# {'Unnamed: 0': 0,
#  'emotion': "['upset', 'frustrated', 'unsatisfied']",
#  'plutchik': "{'joy': 0, 'trust': 0, 'fear': 0, 'surprise': 1, 'sadness': 1, 'disgust': 0, 'anger': 0, 'anticipation': 2}",
#  'selection0': 'The captain gasped and they hit the underside of the boat.',
#  'selection1': 'Reading and the motion of the bus soon lulled him to sleep.',
#  'selection2': 'I fell and hurt my back.',
#  'selection3': 'Then she realized she was out of butter.',
#  'selection4': 'They put new staples in the stapler.',
#  'label': 3}

# %%
def show_one(example):
    print(f"Context: {example['emotion']}")
    print(f"  A - {example['selection0']}")
    print(f"  B - {example['selection1']}")
    print(f"  C - {example['selection2']}")
    print(f"  D - {example['selection3']}")
    print(f"  E - {example['selection4']}")
    print(f"\nGround truth: option {['A', 'B', 'C', 'D', 'E'][example['label']]}")

# %%
show_one(dataset["train"][2])
# Out:
# Context: ['awful', 'upset', 'disappointed', 'embarrassed', 'irritated']
#   A - She felt like she was an adult so she made cup of coffee.
#   B - His mom made an appointment with the barber for next week.
#   C - The toughest gal around wanted to fight.
#   D - She was so uncomfortable, she had to go home.
#   E - This place had the best doughnuts in town.
#
# Ground truth: option D

# %% [markdown]
# # Preprocessing Data

# %%
# from transformers import AutoTokenizer
# tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)
from transformers import DistilBertTokenizer, DistilBertForMultipleChoice
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-cased")
# Out:
# loading file https://huggingface.co/distilbert-base-cased/resolve/main/vocab.txt from cache at C:\Users\JAM_0/.cache\huggingface\transformers\ba377304984dc63e3ede0e23a938bbbf04d5c3835b66d5bb48343aecca188429.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# loading file https://huggingface.co/distilbert-base-cased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/distilbert-base-cased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/distilbert-base-cased/resolve/main/tokenizer_config.json from cache at C:\Users\JAM_0/.cache\huggingface\transformers\81e970e5e6ec68be12da0f8f3b2f2469c78d579282299a2ea65b4b7441719107.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# loading configuration file https://huggingface.co/distilbert-base-cased/resolve/main/config.json from cache at C:\Users\JAM_0/.cache\huggingface\transformers\ebe1ea24d11aa664488b8de5b21e33989008ca78f207d4e30ec6350b693f073f.302bfd1b5e031cc1b17796e0b6e5b242ba2045d31d00f97589e12b458ebff27a
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-cased",
#   "activation": "gelu",
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.19.2",
#   "vocab_size": 28996
# }

# %%
selectionList = ["selection0", "selection1", "selection2", "selection3", "selection4"]

def preprocess_function(examples):
    # Repeat each first sentence four times to go with the four possibilities of second sentences.
    first_sentences = [["The following sentences contain emotions: {}".format(context.strip("[").strip("]").replace('\'', '')) ]*5 for context in examples["emotion"]]
    # Grab all second sentences possible for each context.
    second_sentences = [[examples[selection][index] for selection in selectionList] for index in range(len(examples['selection0']))]

    # Flatten everything
    first_sentences = sum(first_sentences, [])
    second_sentences = sum(second_sentences, [])
    
    # Tokenize
    tokenized_examples = tokenizer(first_sentences, second_sentences, truncation=True)
    # Un-flatten
    # print(tokenized_examples.items())
    return {k: [v[i:i+5] for i in range(0, len(v), 5)] for k, v in tokenized_examples.items()}

# %%
examples = dataset["train"][:5]
features = preprocess_function(examples)
print(len(features["input_ids"]), len(features["input_ids"][0]), [len(x) for x in features["input_ids"][0]])
# Out:
# 5 5 [21, 25, 20, 23, 32]

# %%
[tokenizer.decode(features["input_ids"][a][i]) for a in range(5) for i in range(5) ]
# Out:
# ['[CLS] The following sentences contain emotions : okay, part, included [SEP] Ricky called his dad for help. [SEP]',
#  '[CLS] The following sentences contain emotions : okay, part, included [SEP] Neil was impressed by the amount of work done there. [SEP]',
#  '[CLS] The following sentences contain emotions : okay, part, included [SEP] She ran to the bathroom. [SEP]',
#  '[CLS] The following sentences contain emotions : okay, part, included [SEP] He bought the ticket through a proxy. [SEP]',
#  "[CLS] The following sentences contain emotions : okay, part, included [SEP] Andrea didn't want to be an outcast, so she ate the ice cream. [SEP]",
#  '[CLS] The following sentences contain emotions : pro, anxious, rushed [SEP] I stopped at a blockbuster video store. [SEP]',
#  '[CLS] The following sentences contain emotions : pro, anxious, rushed [SEP] She read that the inside of a banana peel helps stop the itch. [SEP]',
#  "[CLS] The following sentences contain emotions : pro, anxious, rushed [SEP] Ben's wristwatch had stopped working. [SEP]",
#  '[CLS] The following sentences contain emotions : pro, anxious, rushed [SEP] Cameron looked outside the open door of the plane. [SEP]',
#  '[CLS] The following sentences contain emotions : pro, anxious, rushed [SEP] So I sped it up. [SEP]',
#  '[CLS] The following sentences contain emotions : awful, upset, disappointed, embarrassed, irritated [SEP] She felt like she was an adult so she made cup of coffee. [SEP]',
#  '[CLS] The following sentences contain emotions : awful, upset, disappointed, embarrassed, irritated [SEP] His mom made an appointment with the barber for next week. [SEP]',
#  '[CLS] The following sentences contain emotions : awful, upset, disappointed, embarrassed, irritated [SEP] The toughest gal around wanted to fight. [SEP]',
#  '[CLS] The following sentences contain emotions : awful, upset, disappointed, embarrassed, irritated [SEP] She was so uncomfortable, she had to go home. [SEP]',
#  '[CLS] The following sentences contain emotions : awful, upset, disappointed, embarrassed, irritated [SEP] This place had the best doughnuts in town. [SEP]',
#  '[CLS] The following sentences contain emotions : bored, impatient, annoyed [SEP] They objected to their union. [SEP]',
#  "[CLS] The following sentences contain emotions : bored, impatient, annoyed [SEP] One of my daughter's friends got married a few days ago. [SEP]",
#  "[CLS] The following sentences contain emotions : bored, impatient, annoyed [SEP] The baby settled in Chad's lap at the bottom of the stairs. [SEP]",
#  '[CLS] The following sentences contain emotions : bored, impatient, annoyed [SEP] I began to get tired of using the same crayons. [SEP]',
#  '[CLS] The following sentences contain emotions : bored, impatient, annoyed [SEP] Ellen had a huge crush on her classmate Evan. [SEP]',
#  '[CLS] The following sentences contain emotions : dirty, upset [SEP] Amy went camping. [SEP]',
#  '[CLS] The following sentences contain emotions : dirty, upset [SEP] So on her next test, she failed a question, got a B and was happy. [SEP]',
#  '[CLS] The following sentences contain emotions : dirty, upset [SEP] Her hair was so greasy! [SEP]',
#  '[CLS] The following sentences contain emotions : dirty, upset [SEP] Bill was on boating while on holiday. [SEP]',
#  '[CLS] The following sentences contain emotions : dirty, upset [SEP] She was expecting to eat a nice dinner that night. [SEP]']

# %%
encoded_datasets = dataset.map(preprocess_function, batched=True)
# Out:
# Loading cached processed dataset at C:\Users\JAM_0\.cache\huggingface\datasets\csv\default-b12ec4739f83f5c3\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-0fd377198e38974e.arrow
# Loading cached processed dataset at C:\Users\JAM_0\.cache\huggingface\datasets\csv\default-b12ec4739f83f5c3\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-7cccb7787020fcf0.arrow

# %% [markdown]
# # Fine-tuning the model

# %%
from transformers import AutoModelForMultipleChoice, TrainingArguments, Trainer
from transformers import DistilBertTokenizer, DistilBertForMultipleChoice
import torch
model = DistilBertForMultipleChoice.from_pretrained("distilbert-base-cased")

# model = AutoModelForMultipleChoice.from_pretrained(model_checkpoint)
# Out:
# loading configuration file https://huggingface.co/distilbert-base-cased/resolve/main/config.json from cache at C:\Users\JAM_0/.cache\huggingface\transformers\ebe1ea24d11aa664488b8de5b21e33989008ca78f207d4e30ec6350b693f073f.302bfd1b5e031cc1b17796e0b6e5b242ba2045d31d00f97589e12b458ebff27a
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.19.2",
#   "vocab_size": 28996
# }
#
# loading weights file https://huggingface.co/distilbert-base-cased/resolve/main/pytorch_model.bin from cache at C:\Users\JAM_0/.cache\huggingface\transformers\9c9f39769dba4c5fe379b4bc82973eb01297bd607954621434eb9f1bc85a23a0.06b428c87335c1bb22eae46fdab31c8286efa0aa09e898a7ac42ddf5c3f5dc19
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForMultipleChoice: ['vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForMultipleChoice from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForMultipleChoice from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForMultipleChoice were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_name = model_checkpoint.split("/")[-1]
args = TrainingArguments(
    f"{model_name}-finetuned-emotionCommonsense",
    evaluation_strategy = "epoch",
    #learning_rate=5e-5, # for bert-base
    learning_rate=5e-5, # for roberta-base
    # learning_rate=1e-3,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_epochs,
    weight_decay=0.01,
    push_to_hub=False,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
from dataclasses import dataclass
from transformers.tokenization_utils_base import PreTrainedTokenizerBase, PaddingStrategy
from typing import Optional, Union
import torch

@dataclass
class DataCollatorForMultipleChoice:
    """
    Data collator that will dynamically pad the inputs for multiple choice received.
    """

    tokenizer: PreTrainedTokenizerBase
    padding: Union[bool, str, PaddingStrategy] = True
    max_length: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None

    def __call__(self, features):
        label_name = "label" if "label" in features[0].keys() else "labels"
        labels = [feature.pop(label_name) for feature in features]
        batch_size = len(features)
        num_choices = len(features[0]["input_ids"])
        flattened_features = [[{k: v[i] for k, v in feature.items()} for i in range(num_choices)] for feature in features]
        flattened_features = sum(flattened_features, [])
        
        batch = self.tokenizer.pad(
            flattened_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        
        # Un-flatten
        batch = {k: v.view(batch_size, num_choices, -1) for k, v in batch.items()}
        # Add back labels
        batch["labels"] = torch.tensor(labels, dtype=torch.int64)
        return batch

# %%
accepted_keys = ["input_ids", "attention_mask", "label"]
features = [{k: v for k, v in encoded_datasets["train"][i].items() if k in accepted_keys} for i in range(10)]
batch = DataCollatorForMultipleChoice(tokenizer)(features)

# %%
[tokenizer.decode(batch["input_ids"][8][i].tolist()) for i in range(5)]
# Out:
# ['[CLS] The following sentences contain emotions : enjoyed, happy [SEP] Six months later, the skinny guy could bench press 200 lbs! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] The following sentences contain emotions : enjoyed, happy [SEP] A few months later I was running well over five miles at once! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] The following sentences contain emotions : enjoyed, happy [SEP] She said to hurry up since the breakfast was getting cold. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] The following sentences contain emotions : enjoyed, happy [SEP] I went to a party. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] The following sentences contain emotions : enjoyed, happy [SEP] I decided to leave and purchase a phone online. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]']

# %%
show_one(dataset["train"][8])
# Out:
# Context: ['enjoyed', 'happy']
#   A - Six months later, the skinny guy could bench press 200 lbs!
#   B - A few months later I was running well over five miles at once!
#   C - She said to hurry up since the breakfast was getting cold.
#   D - I went to a party.
#   E - I decided to leave and purchase a phone online.
#
# Ground truth: option D

# %% [markdown]
# # Trainer Defined

# %%
import numpy as np

valStored = []
def compute_metrics(eval_predictions):
    predictions, label_ids = eval_predictions
    preds = np.argmax(predictions, axis=1)
    valStored.append((preds != label_ids).astype(np.float32));
    return {"accuracy": (preds == label_ids).astype(np.float32).mean().item()}

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=encoded_datasets["train"],
    eval_dataset=encoded_datasets["test"],
    tokenizer=tokenizer,
    data_collator=DataCollatorForMultipleChoice(tokenizer),
    compute_metrics=compute_metrics,
)

# %%
# !nvidia-smi
# Out:
# Fri Jun 24 08:26:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 511.65       Driver Version: 511.65       CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   42C    P3    93W / 370W |   9455MiB / 10240MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       448    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      1492    C+G                                   N/A      |
# |    0   N/A  N/A      8512    C+G   ...d\runtime\WeChatAppEx.exe    N/A      |
# |    0   N/A  N/A      8708      C   ...EnvWithDataSci\python.exe    N/A      |
# |    0   N/A  N/A      9632    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     10292    C+G   ...er_engine\wallpaper64.exe    N/A      |
# |    0   N/A  N/A     10796    C+G                                   N/A      |
# |    0   N/A  N/A     10996      C   ...EnvWithDataSci\python.exe    N/A      |
# |    0   N/A  N/A     12416    C+G   ...bbwe\HxCalendarAppImm.exe    N/A      |
# |    0   N/A  N/A     13644    C+G   ...8bbwe\Microsoft.Notes.exe    N/A      |
# |    0   N/A  N/A     13832    C+G                                   N/A      |
# |    0   N/A  N/A     14480    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     14820      C   ...EnvWithDataSci\python.exe    N/A      |
# |    0   N/A  N/A     14880    C+G   ...tracted\WechatBrowser.exe    N/A      |
# |    0   N/A  N/A     15816    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     15972    C+G   ...e\root\Office16\EXCEL.EXE    N/A      |
# |    0   N/A  N/A     16052    C+G   ...\dependencies\washost.exe    N/A      |
# |    0   N/A  N/A     16340    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     16604    C+G   ...urrent\LogiOptionsMgr.exe    N/A      |
# |    0   N/A  N/A     16628    C+G   ...e\Current\LogiOverlay.exe    N/A      |
# |    0   N/A  N/A     19004    C+G   ...root\Office16\WINWORD.EXE    N/A      |
# |    0   N/A  N/A     19884    C+G   ...\app-1.0.9005\Discord.exe    N/A      |
# |    0   N/A  N/A     20416      C   ...EnvWithDataSci\python.exe    N/A      |
# |    0   N/A  N/A     20484      C   ...EnvWithDataSci\python.exe    N/A      |
# |    0   N/A  N/A     21732    C+G   ...245.44\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     22292    C+G   ...tracted\WechatBrowser.exe    N/A      |
# |    0   N/A  N/A     23456    C+G   ...ck\app-4.27.154\slack.exe    N/A      |
# |    0   N/A  N/A     23568    C+G   ...8wekyb3d8bbwe\Cortana.exe    N/A      |
# |    0   N/A  N/A     24108    C+G   ...ncher\CiscoCollabHost.exe    N/A      |
# |    0   N/A  N/A     27420    C+G   ...oot\Office16\POWERPNT.EXE    N/A      |
# |    0   N/A  N/A     27812    C+G   ...245.44\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     27900    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     32104    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     34200    C+G   ...erver\YourPhoneServer.exe    N/A      |
# |    0   N/A  N/A     34272    C+G   ...em32\DataExchangeHost.exe    N/A      |
# |    0   N/A  N/A     34756    C+G   ...ncher\CiscoCollabHost.exe    N/A      |
# |    0   N/A  N/A     35280    C+G   ...8bbwe\WindowsTerminal.exe    N/A      |
# |    0   N/A  N/A     35888    C+G   ...8bbwe\WindowsTerminal.exe    N/A      |
# |    0   N/A  N/A     36392    C+G   ...2\extracted\WeChatApp.exe    N/A      |
# |    0   N/A  N/A     37416    C+G   ...ekyb3d8bbwe\HxOutlook.exe    N/A      |
# |    0   N/A  N/A     37608    C+G   ...n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A     38244    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     38768    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     39024      C   ...EnvWithDataSci\python.exe    N/A      |
# |    0   N/A  N/A     42356    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     43104    C+G   ...n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A     43448      C   ...EnvWithDataSci\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce RTX 3080
# Memory Usage:
# Allocated: 0.2 GB
# Cached:    4.4 GB

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# C:\Python\miniconda3\envs\pytorchEnvWithDataSci\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 11610
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 11616
#     <div>
#
#       <progress value='11616' max='11616' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11616/11616 24:10, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.306000</td>
#       <td>0.937792</td>
#       <td>0.635098</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.909800</td>
#       <td>0.884820</td>
#       <td>0.662503</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.433200</td>
#       <td>1.038108</td>
#       <td>0.664121</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.300800</td>
#       <td>1.399972</td>
#       <td>0.657292</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.143200</td>
#       <td>2.134427</td>
#       <td>0.660077</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.110300</td>
#       <td>2.471677</td>
#       <td>0.659718</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.091300</td>
#       <td>3.186204</td>
#       <td>0.664750</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.064100</td>
#       <td>3.451330</td>
#       <td>0.661874</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.044700</td>
#       <td>3.694110</td>
#       <td>0.667805</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.029100</td>
#       <td>3.897564</td>
#       <td>0.670501</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.032100</td>
#       <td>4.438231</td>
#       <td>0.670770</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.026500</td>
#       <td>4.483102</td>
#       <td>0.669692</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.016400</td>
#       <td>4.821724</td>
#       <td>0.673106</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.009600</td>
#       <td>4.936388</td>
#       <td>0.677599</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.007300</td>
#       <td>4.918184</td>
#       <td>0.680744</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.005900</td>
#       <td>5.005414</td>
#       <td>0.679666</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-1500\special_tokens_map.json
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-2500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3000\special_tokens_map.json
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-3500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-4500\special_tokens_map.json
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-5500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6000\special_tokens_map.json
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-6500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-7500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8000\special_tokens_map.json
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-8500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-9500\special_tokens_map.json
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-10500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11000
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11000\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11000\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11000\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11000\special_tokens_map.json
# Saving model checkpoint to bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11500
# Configuration saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11500\config.json
# Model weights saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11500\pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11500\tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-emotionCommonsense\checkpoint-11500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForMultipleChoice.forward` and have been ignored: selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4. If selection3, emotion, selection1, plutchik, selection0, selection2, Unnamed: 0, selection4 are not expected by `DistilBertForMultipleChoice.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 11129
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=11616, training_loss=0.20235659176940432, metrics={'train_runtime': 1451.1694, 'train_samples_per_second': 128.007, 'train_steps_per_second': 8.005, 'total_flos': 9630854940072600.0, 'train_loss': 0.20235659176940432, 'epoch': 16.0})

# %% [markdown]
# 出现validation loss 上升情况大多是训练集验证集数据分布不一致，或者训练集过小，未包含验证集中所有情况，
# 也就是过拟合导致的。而解决这种现象可以尝试以下几种策略：
# 1. 增加训练样本增加正则项系数权重，
# 2. 减小过拟合加入早停机制，ValLoss上升几个epoch直接停止
# 3. 采用Focal Loss
# 4. 加入Label Smoothing

# %% [markdown]
# # Store Value

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

Z = np.transpose(valStored)

fig, ax = plt.subplots()
ax.pcolormesh(Z)

# %%
import pandas as pd
if model_checkpoint == 'distilbert-base-uncased-finetuned-sst-2-english':
    model_checkpoint = 'distilbert-base'
dataLog = pd.DataFrame(trainer.state.log_history)
dataLog.to_csv(f'./trainingMetric/[Emotion] 5Select/TI-{model_checkpoint}-{fileTag}.csv')

# %%
evaluationIterationResult = pd.DataFrame(np.transpose(valStored))
evaluationIterationResult.to_csv(f'./trainingMetric/[Emotion] 5Select/ESI-{model_checkpoint}-{fileTag}.csv')
